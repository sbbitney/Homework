# %%
import csv 
import os
votes = 0
candidates = []

voterCount={}

winningvotes = 0
finalCandidate = ""

# winvotes = 0
# winninCand=''



with open("Resources/election_data.csv") as f:
    reader = csv.reader(f)
    next(reader) # skip header
    for row in reader: #read through the data
        votes += 1
        
#open the file and read it
#loop through the data and count each vote
#return the total number of votes
#print(votes)




candidate = row[2]
if candidate not in candidates:
            candidates.append(candidate)
            voterCount[candidates] = 0
        
else:
            voterCount[candidate] += 1



#identify each individual candidate who received votes and create a list of them
 #totalVotes=totalVotes + 1


# for item in voterCount:
#    thisCandVotes = voterCount[item]
#    candidate = item
   
#    if thisCandVotes > winvotes:
       
#        winCand = candidate
#        winvotes = thisCandVotes

# print(winCand)
# print(winvotes)
# print(round(winvotes/totalVotes*100, 1))


# election_results = (
#    f"\n\nElection Results\n"
#    f"-------------------------\n"
#    f"Total Votes: {totalVotes}\n"
#    f"-------------------------\n"
#    f"The Wining Candidate:{winCand}\n"
#    f"The wining count: {winvotes}\n"
#    f"Wining % : {round(winvotes/totalVotes*100, 1)}")


   
   
   
# with open(file_to_output, 'w') as textfile:
#    textfile.write(election_results)

#get percentage of votes each candidate won
#iterate through the list, adding 1 each time the candidate name is mentioned



#display total votes per candidate

#display caniddate with most votes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e7583a721428> in <module>()
#      31 if candidate not in candidates:
#      32             candidates.append(candidate)
# ---> 33             voterCount[candidates] = 0
#      34
#      35 else:
#
# TypeError: unhashable type: 'list'

# %%
pathName = os.getcwd()

numFiles = []
fileNames = os.listdir(pathName)
for fileNames in fileNames:
    if fileNames.endswith(".csv"):
        numFiles.append(fileNames)

for i in numFiles:
    file = open(os.path.join(pathName, i), "rU")
    reader = csv.reader(file, delimiter=',')
    for column in reader:
        print(column[4])
