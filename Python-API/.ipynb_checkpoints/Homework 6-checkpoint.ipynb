# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time

#Randomly select at least 500 unique (non-repeat) cities based on latitude and longitude.
#Perform a weather check on each of the cities using a series of successive API calls.
#Include a print log of each city as it's being processed with the city number and city name.
#Save both a CSV of all data retrieved and png images for each scatter plot.

#goes to that URL and gets the information
from citipy import citipy
import folium

# %%
#weather['main']['temp_max']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-765e703b3746> in <module>()
# ----> 1 weather['main']['temp_max']
#
# NameError: name 'weather' is not defined

# %%
latitude = np.random.uniform(low = -90.000, high = 90.000, size = 50)
longitude = np.random.uniform(low = -180.000, high = 180.000, size = 50)

city_list = []
for i in range(len(latitude)):
    lat = latitude[i]
    long = longitude[i]
    city = citipy.nearest_city(lat, long).city_name
    country = citipy.nearest_city(lat, long).country_code
    #if not on city_list:
    city_list.append((city, country))

# %%
weather_data =[]

mapBase = folium.Map(location=[30,0], tiles = "Mapbox Bright", zoom_start = 2)


API = 'd791bbcdf03e043bbd2316f92982a22b'
URL = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + API


counter = 0
for city in city_list:
# print(city)
    city_url = URL + "&q=" + city[0] + ',' + city[1]
    counter +=1
    print(counter)
    print(f"City is: {city[0]}, {city[1]}")
    print(f"URL is {city_url}")

    #print(weather)
    #print("")
    try:

        weather = requests.get(city_url).json()
        
        lat       = weather['coord'] ['lat']
        long      = weather['coord'] ['long']
        max_temp  = weather['main'] ['temp_max']
        humidity  = weather['main'] ['humidity']
        clouds    = weather['clouds'] ['all']
        windspeed = weather['winds'] ['speed']
        winddeg   = weather['winds'] ['deg']
        date      = weather['dt']
        
        weather = {"lat"      : lat,
                  "long"      : long,
                  "Max temp"  : max_temp,
                  "Humidity"  : humidity,
                  "Cloudiness": clouds,
                  "wind speed": windspeed,
                  "Wind deg"  : winddeg,
                  "Date"      : date}
        
        temp= max_temp
        print(f"the maximum temperature is: {temp}")

        weather_data.append(weather)
 
 #       foium.Circle(location=[lat, long],
  #                  popup=Temp,
  #                  radius=int(humidity)*1000
  #                  ).add_to(mapBase)
        print("_________")
        print(weather_data)
        print("_________")

    except:
        print("not found") 
        pass
#mapbase is from import folium

#A scatter plot for each
#Temperature (F) vs. Latitude

#Humidity (%) vs. Latitude

#Cloudiness (%) vs. Latitude

#Wind Speed (mph) vs. Latitude


#1 create random numbers for locations (latitudes and longitudes)
#size = number of times we're going to do it. 

#lats[0], lngs[0]
#this gives us a combination of lat and long, which gives us a city 


#2 for each combo of random lat and longitudes, go to the city pie which will provide the nearest city for 
#that location

#once generated nearest city and country, can build the associated URL.  (the URL provided, plus the ID plus 
#the query)

#4 for each city, visit that URL and get a JSON object for that city weather via the git response.  

#5 after that, save it in an object, like current_city_info

#6 put this information into a container, like a dictionary

#7 all dictionaries pushed one by one to a list.

#8 put it into a pandas dataframe, provide the list. 


#LOOK AT SEABORN AND PANDAS FOR PLOTTING TOOLS



#saving works?
# Out:
# 1
# City is: hobart, au
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=hobart,au
#
# not found
# 2
# City is: xingcheng, cn
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=xingcheng,cn
#
# not found
# 3
# City is: bengkulu, id
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=bengkulu,id
#
# not found
# 4
# City is: albany, au
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=albany,au
#
# not found
# 5
# City is: awjilah, ly
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=awjilah,ly
#
# not found
# 6
# City is: bara, sd
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=bara,sd
#
# not found
# 7
# City is: seoul, kr
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=seoul,kr
#
# not found
# 8
# City is: krasnoselkup, ru
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=krasnoselkup,ru
#
# not found
# 9
# City is: necochea, ar
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=necochea,ar
#
# not found
# 10
# City is: wonthaggi, au
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=wonthaggi,au
#
# not found
# 11
# City is: dikson, ru
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=dikson,ru
#
# not found
# 12
# City is: bredasdorp, za
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=bredasdorp,za
#
# not found
# 13
# City is: velsk, ru
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=velsk,ru
#
# not found
# 14
# City is: muana, br
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=muana,br
#
# not found
# 15
# City is: nikolskoye, ru
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=nikolskoye,ru
#
# not found
# 16
# City is: nikolskoye, ru
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=nikolskoye,ru
#
# not found
# 17
# City is: dongkan, cn
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=dongkan,cn
#
# not found
# 18
# City is: tasiilaq, gl
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=tasiilaq,gl
#
# not found
# 19
# City is: busselton, au
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=busselton,au
#
# not found
# 20
# City is: hirara, jp
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=hirara,jp
#
# not found
# 21
# City is: mantua, cu
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=mantua,cu
#
# not found
# 22
# City is: manicore, br
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=manicore,br
#
# not found
# 23
# City is: buala, sb
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=buala,sb
#
# not found
# 24
# City is: fortuna, us
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=fortuna,us
#
# not found
# 25
# City is: tura, ru
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=tura,ru
#
# not found
# 26
# City is: kapaa, us
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=kapaa,us
#
# not found
# 27
# City is: barrow, us
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=barrow,us
#
# not found
# 28
# City is: kapit, my
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=kapit,my
#
# not found
# 29
# City is: chapais, ca
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=chapais,ca
#
# not found
# 30
# City is: butaritari, ki
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=butaritari,ki
#
# not found
# 31
# City is: kamaishi, jp
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=kamaishi,jp
#
# not found
# 32
# City is: ushuaia, ar
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=ushuaia,ar
#
# not found
# 33
# City is: rikitea, pf
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=rikitea,pf
#
# not found
# 34
# City is: albany, au
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=albany,au
#
# not found
# 35
# City is: invermere, ca
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=invermere,ca
#
# not found
# 36
# City is: prieska, za
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=prieska,za
#
# not found
# 37
# City is: ilulissat, gl
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=ilulissat,gl
#
# not found
# 38
# City is: saskylakh, ru
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=saskylakh,ru
#
# not found
# 39
# City is: port keats, au
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=port keats,au
#
# not found
# 40
# City is: azimur, ma
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=azimur,ma
#
# not found
# 41
# City is: lasa, cn
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=lasa,cn
#
# not found
# 42
# City is: bengkulu, id
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=bengkulu,id
#
# not found
# 43
# City is: samusu, ws
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=samusu,ws
#
# not found
# 44
# City is: pevek, ru
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=pevek,ru
#
# not found
# 45
# City is: rikitea, pf
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=rikitea,pf
#
# not found
# 46
# City is: cabo san lucas, mx
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=cabo san lucas,mx
#
# not found
# 47
# City is: vaini, to
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=vaini,to
#
# not found
# 48
# City is: coquimbo, cl
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=coquimbo,cl
#
# not found
# 49
# City is: hilo, us
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=hilo,us
#
# not found
# 50
# City is: portland, au
# URL is http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d791bbcdf03e043bbd2316f92982a22b&q=portland,au
#
# not found

# %%
mapBase
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df = pd.DataFrame(weather_data)
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
plt.scatter(df.long,
            df.lat,
            edgecolor="red", 
            linewidths=.15, marker='o',
            alpha=.5, label="weather cities")

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.legend(loc = 'upper center', bbox_to_anchor = (0.5, 1.12),
          ncol = 3, fancybox = True, shadow = True)

plt.grid = True

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-79c6f263316f> in <module>()
# ----> 1 plt.scatter(df.long,
#       2             df.lat,
#       3             edgecolor="red",
#       4             linewidths=.15, marker='o',
#       5             alpha=.5, label="weather cities")
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'long'

# %%
lats = df.lat
max_temps=df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-7f0a878f283c> in <module>()
# ----> 1 lats = df.lat
#       2 max_temps=df
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'lat'
