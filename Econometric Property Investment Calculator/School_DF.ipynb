# %%
import pandas as pd
import numpy as np

# %%
filenames = ["Elementary_School_Ratings.csv", "middle_School_Ratings.csv", "High_School_Ratings.csv", "new_High_School_Ratings.csv"] # Fill in remaining files.
df = pd.DataFrame()
for filename in filenames:
    print(filename)
    df = df.append(pd.read_csv(filename, encoding="ISO-8859-1"), sort=False)
# Out:
# Elementary_School_Ratings.csv
# middle_School_Ratings.csv
# High_School_Ratings.csv
# new_High_School_Ratings.csv

# %%
df

# %%
df["zipcode"] = ""

# %%
for index, row in df.iterrows():
    try: 
        zipcode = (row["School Address"].split("TX  ")[1])
        df.set_value(index, "zipcode", zipcode)
    except:
        df.set_value(index, "zipcode", np.nan)
#     print(row["School Name"])
    if ("Jail" in row["School Name"]):
        df.drop(index)
#         print("found jail")
    if ("Hospital" in row["School Name"]):
        df.drop(index)
#     if ("Texas School For The Blind" in row["School Name"]):
#         df.drop(index)
#         print("yahtzee")
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
df = df.dropna()
df.drop_duplicates(subset=None, keep='first', inplace=False)

# %%
df.tail(3000)
# Out:
#       Unnamed: 0   Latitude  Longitude                       School Name  \
# 5669        5669  30.321456 -97.793892                          Rosedale
# 5670        5670  30.367918 -97.685651                Lanier High School
# 5671        5671  30.437885 -97.889674            Cedar Park High School
# 5672        5672  30.335599 -97.877512            Vandegrift High School
# 5673        5673  30.473417 -97.834073            Cedar Park High School
# 5674        5674  30.377428 -97.655971       John B Connally High School
# 5675        5675  30.236285 -97.992563           Lake Travis High School
# 5676        5676  30.374549 -97.937601            Lago Vista High School
# 5677        5677  30.158036 -97.804800                 Akins High School
# 5678        5678  30.211196 -97.778474              Crockett High School
# 5679        5679  30.500625 -97.598293           Hendrickson High School
# 5680        5680  30.147127 -97.810898                 Akins High School
# ...

# %%
df.to_csv('keep_duplicate_school_data.csv', index=False)
